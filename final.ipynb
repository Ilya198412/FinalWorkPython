# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
# f(x) = -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30

# a = int(input('a'))
# b = int(input('b'))
# c = int(input('c'))
# d = int(input('d'))
# e = int(input('e'))

a,b,c,d,e = 12,18,5,10,30


x = list(range(-250,250))
# fx = [-12*np.sin(np.cos(i))*i**4 - 18*i**3+5*i**2 +10*i -30 for i in x]
fx = [-a*np.sin(np.cos(i))*i**4 - b*i**3+c*i**2 +d*i -e for i in x]
plt.plot(fx)
plt.xlabel('Ось X')
plt.ylabel('Ось Y')
# Out:
# Text(0, 0.5, 'Ось Y')
